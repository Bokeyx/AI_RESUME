# %% [markdown]
# # 이력서 전처리 및 정보 추출 모듈

# %% [markdown]
# ### 라이브러리 임포트

# %%
# 라이브러리 임포트 및 기본 설정
import pandas as pd
import numpy as np
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import unicodedata
import json
from collections import Counter
from spacy.matcher import Matcher
import logging

# 로깅 설정 (정보 수준 메시지 출력)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# NLTK 리소스 다운로드
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
# Out:
# True

# %%
# spaCy 모델 로드
nlp = spacy.load("en_core_web_sm")
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# 카테고리별 기술 키워드 정의
CATEGORY_KEYWORDS = {
    "Data Science": ["python", "machine learning", "pandas", "numpy", "deep learning", "tensorflow", "pytorch", "html", "matlab"],
    "Web Designing": ["photoshop", "figma", "adobe", "html", "css", "ux", "ui", "javascript", "react"],
    "HR": ["recruiting", "training", "interview", "employee", "onboarding", "talent"],
    "Advocate": ["litigation", "legal", "court", "civil", "criminal", "case"],
    "Health and fitness": ["fitness", "nutrition", "yoga", "wellness", "trainer"],
    "Java Developer": ["java", "spring", "hibernate", "j2ee", "jdbc"],
    "Python Developer": ["python", "django", "flask", "api", "pandas"],
    "DevOps Engineer": ["docker", "kubernetes", "jenkins", "terraform", "aws"],
    "Business Analyst": ["analysis", "report", "requirement", "power bi", "workflow"],
    "Electrical Engineering": ["circuit", "voltage", "control", "plc", "switchgear"],
    "Testing": ["selenium", "junit", "qa", "test automation", "bug tracking"],
    "Blockchain": ["blockchain", "ethereum", "smart contract", "cryptocurrency"]
}

TECH_KEYWORDS = [
    'python', 'java', 'c++', 'c', 'sql', 'mysql', 'mongodb', 'postgresql',
    'machine learning', 'deep learning', 'pytorch', 'tensorflow',
    'html', 'css', 'javascript', 'react', 'angular', 'node.js',
    'flask', 'spring boot', 'git', 'docker', 'aws', 'linux'
]

# %%
# Preprocessing 클래스 정의
class Preprocessing:
    def __init__(self):
        self.matcher = Matcher(nlp.vocab)
        self.degree_keywords = ["b.tech", "b.e.", "m.tech", "mca", "bachelor", "master", "ph.d", "diploma"]
        self.setup_matcher()

    def setup_matcher(self):
        """학력 패턴 설정"""
        degree_patterns = [
            [{"LOWER": {"REGEX": r"^(b\.tech|b\.e\.|m\.tech|mca|bachelor|master|ph\.d|diploma)$"}}],
            [{"TEXT": {"IN": [kw.lower() for kw in self.degree_keywords]}}]
        ]
        self.matcher.add("EDUCATION", degree_patterns)

    def clean_text(self, text, remove_numbers=False, remove_dates=True):
        """텍스트 정제: 유니코드 정규화, 특수문자 제거, 불용어 제거, 표제어 추출"""
        try:
            text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii')
            text = text.lower()
            text = re.sub(r'[^a-z0-9\s]', ' ', text)
            text = re.sub(r'\s+', ' ', text).strip()
            tokens = word_tokenize(text)
            tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words and len(w) > 2]
            if remove_numbers:
                tokens = [w for w in tokens if not w.isdigit()]
            if remove_dates:
                date_words = {'january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december'}
                tokens = [w for w in tokens if w not in date_words]
            # 연도 및 경험 기간 유지
            tokens = tokens + re.findall(r'\d+\s*(?:year|years)\s*(?:experience)?', text)
            return ' '.join(tokens)
        except Exception as e:
            logging.error(f"Text cleaning failed: {str(e)}")
            return text

    def get_skill_patterns(self, keywords):
        """기술 키워드에 대한 정규식 패턴 생성"""
        patterns = []
        for kw in keywords:
            if all(c.isalnum() or c == '_' for c in kw.replace(' ', '')):
                pattern = r'\b' + re.escape(kw) + r'\b'
            else:
                pattern = re.escape(kw)
            pattern = pattern.replace(r'\ ', r'\s+')
            patterns.append((pattern, kw))
        return patterns

    def extract_skills(self, text, category):
        """기술 키워드 추출: 원본 텍스트 사용"""
        all_keywords = CATEGORY_KEYWORDS.get(category, []) + TECH_KEYWORDS
        all_keywords = list(set(all_keywords))
        patterns = self.get_skill_patterns(all_keywords)
        text_lower = text.lower()
        skills = []
        for pattern, kw in patterns:
            if re.search(pattern, text_lower):
                skills.append(kw)
        logging.info(f"Extracted skills: {skills}")
        return list(set(skills))

    def extract_education(self, text):
        """학력 정보 추출: 학위, 기관, 연도"""
        try:
            doc = nlp(text)
            matches = self.matcher(doc)
            degrees = set(doc[start:end].text.lower() for match_id, start, end in matches)

            # 정규식으로 학위 보조 매칭
            for kw in self.degree_keywords:
                if re.search(r'\b' + re.escape(kw) + r'\b', text.lower(), re.IGNORECASE):
                    degrees.add(kw.lower())
            degrees = sorted(list(degrees))

            education = []
            exclude_keywords = {'education', 'recognition', 'details', 'secondary', 'skill', 'exprience', 'company'}
            institution_patterns = r'(?:institute|university|college|academy|school|of\s+[a-z]+)\b'

            # 전체 텍스트에서 연도 먼저 검색
            year_pattern = r'(?:january|february|march|april|may|june|july|august|september|october|november|december)?\s*\d{4}\s*(?:to|-)\s*(?:january|february|march|april|may|june|july|august|september|october|november|december)?\s*\d{4}'
            year_match = re.search(year_pattern, text.lower(), re.IGNORECASE)
            default_year = year_match.group(0) if year_match else None

            # 문장 병합: 학위 포함 문장 + 다음 문장
            sentences = list(doc.sents)
            for i, sent in enumerate(sentences):
                sent_text = sent.text
                sent_lower = sent_text.lower()
                if any(re.search(r'\b' + re.escape(d) + r'\b', sent_lower, re.IGNORECASE) for d in degrees):
                    combined_text = sent_text
                    if i + 1 < len(sentences):
                        combined_text += ' ' + sentences[i + 1].text
                    combined_lower = combined_text.lower()

                    # 기관명 추출
                    orgs = [ent.text for ent in nlp(combined_text).ents if ent.label_ == "ORG" and not any(kw in ent.text.lower() for kw in exclude_keywords)]
                    if not orgs:
                        inst_match = re.search(institution_patterns, combined_lower, re.IGNORECASE)
                        if inst_match:
                            start_idx = max(0, combined_lower.find(inst_match.group(0)) - 150)
                            end_idx = combined_lower.find(inst_match.group(0)) + 200
                            org_text = combined_text[start_idx:end_idx].split('\r\n')[0].strip()
                            org_text = re.sub(r'\s+', ' ', org_text).strip()
                            if not any(kw in org_text.lower() for kw in exclude_keywords) and len(org_text) > 10:
                                orgs = [org_text]

                    # 연도 추출
                    year = default_year
                    if not year:
                        dates = [ent.text for ent in nlp(combined_text).ents if ent.label_ == "DATE" and re.search(r'\d{4}', ent.text)]
                        year = dates[0] if dates else None

                    if degrees:
                        education.append({
                            "degree": degrees,
                            "institution": orgs[0] if orgs else None,
                            "year": year
                        })
                        break

            # 학위만 발견된 경우
            if not education and degrees:
                education.append({
                    "degree": degrees,
                    "institution": None,
                    "year": default_year
                })

            logging.debug(f"Education extracted: {education}")
            return education[:1]
        except Exception as e:
            logging.error(f"Education extraction failed: {str(e)}")
            return []

    def extract_experience(self, text):
        """경력 정보 추출: 회사, 역할, 기간"""
        try:
            doc = nlp(text)
            experiences = []
            role_keywords = [
                "engineer", "developer", "manager", "analyst", "scientist", "programmer", "specialist",
                "consultant", "designer", "researcher", "architect", "administrator", "technician",
                "operator", "coordinator", "supervisor", "director", "executive", "assistant", "associate",
                "intern", "trainee"
            ]
            exclude_keywords = {
                'education', 'college', 'institute', 'university', 'school', 'secondary', 'exprience',
                'skill', 'details', 'recognition', 'company -', 'academic'
            }
            company_patterns = r'(?:at|with|worked\s+at|employed\s+by)\s+([^,;\r\n]+)'

            for sent in doc.sents:
                sent_text = sent.text.lower()
                if any(kw in sent_text for kw in exclude_keywords):
                    continue

                orgs = [ent.text for ent in sent.ents if ent.label_ == "ORG" and not any(kw in ent.text.lower() for kw in exclude_keywords)]
                if not orgs:
                    company_match = re.search(company_patterns, sent_text, re.IGNORECASE)
                    if company_match:
                        org_text = company_match.group(1).strip()
                        if not any(kw in org_text.lower() for kw in exclude_keywords):
                            orgs = [org_text]

                roles = [token.text for token in sent if token.text.lower() in role_keywords]
                if not roles:
                    # 의존성 파싱으로 역할 추출
                    for token in sent:
                        if token.dep_ in ("nsubj", "dobj") and token.text.lower() in role_keywords:
                            roles.append(token.text)

                dates = [ent.text for ent in sent.ents if ent.label_ == "DATE" and re.search(r'\d{4}', ent.text)]
                if not dates:
                    date_pattern = r'\d{4}(?:\s*(?:to|-)\s*\d{4})?'
                    date_match = re.search(date_pattern, sent_text)
                    if date_match:
                        dates = [date_match.group(0)]

                if orgs and dates:
                    experiences.append({
                        "company": orgs[0],
                        "role": roles[0] if roles else None,
                        "period": dates[0],
                        "description": sent.text.strip()
                    })

            logging.debug(f"Experience extracted: {experiences}")
            return experiences
        except Exception as e:
            logging.error(f"Experience extraction failed: {str(e)}")
            return []

    def process_dataframe(self, df, text_col='Resume', category_col='Category'):
        """데이터프레임 전체 전처리"""
        try:
            df['cleaned_resume'] = df[text_col].apply(lambda x: self.clean_text(x, remove_numbers=False, remove_dates=True))
            df['skills'] = df.apply(lambda row: self.extract_skills(row[text_col], row[category_col]), axis=1)
            docs = list(nlp.pipe(df[text_col]))
            df['education'] = [self.extract_education(doc.text) for doc in docs]
            df['experience'] = [self.extract_experience(doc.text) for doc in docs]
            self.check_class_balance(df, category_col)
            return df
        except Exception as e:
            logging.error(f"Dataframe processing failed: {str(e)}")
            return df

    def check_class_balance(self, df, category_col):
        """클래스 불균형 확인"""
        counts = Counter(df[category_col])
        logging.info("\n카테고리별 샘플 수:")
        for category, count in counts.items():
            logging.info(f"{category}: {count}")
        if max(counts.values()) / min(counts.values()) > 5:
            logging.warning("클래스 불균형 감지. SMOTE 또는 클래스 가중치 적용 고려.")
            # 예: from imblearn.over_sampling import SMOTE
            # smote = SMOTE(random_state=42)
            # X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
def main():
    try:
        file_path = './src/UpdatedResumeDataSet.csv'
        df = pd.read_csv(file_path)
        logging.info(f"데이터 크기: {df.shape}")
        logging.info("\n데이터 정보:")
        logging.info(df.info())
        logging.info("\n카테고리 목록:")
        logging.info(df['Category'].unique())

        preprocessor = Preprocessing()
        df_processed = preprocessor.process_dataframe(df)

        sample_idx = 5
        logging.info(f"\n샘플 인덱스: {sample_idx}")
        logging.info(f"원문 Resume 요약: {df_processed['Resume'][sample_idx][:300]} ...")
        logging.info(f"정제된 Resume: {df_processed['cleaned_resume'][sample_idx][:300]} ...")
        logging.info(f"기술 스택: {df_processed['skills'][sample_idx]}")
        logging.info(f"학력 정보: {df_processed['education'][sample_idx]}")
        logging.info(f"경력 정보: {df_processed['experience'][sample_idx]}")

        output_path = './src/ProcessedResumeDataSet.json'
        df_processed.to_json(output_path, orient='records', lines=True)
        logging.info(f"전처리된 데이터 저장 완료: {output_path}")
    except Exception as e:
        logging.error(f"Main function failed: {str(e)}")

# %%
file_path = './src/UpdatedResumeDataSet.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \nMay 2013 to May 2017 B.E  ...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \n MCA   YMCAUST,  Faridabad...
#
#                                       cleaned_resume  \
# 0  skill programming language python panda numpy ...
# 1  education detail may 2013 may 2017 b.e uitrgpv...
# 2  area interest deep learning control system des...
# 3  skill python sap hana tableau sap hana sql sap...
# 4  education detail mca ymcaust faridabad haryana...
#
#                                               skills     education  \
# 0  ['machine learning', 'numpy', 'deep learning',...            []
# 1                     ['machine learning', 'python']            []
# 2    ['machine learning', 'deep learning', 'python']    ['B.Tech']
# 3    ['machine learning', 'deep learning', 'python']  ['Bachelor']
# 4                                         ['python']       ['MCA']
#
#                                           experience
# 0  ['Education Details \r\n\r\nData Science Assur...
# 1  ['Education Details \r\nMay 2013 to May 2017 B...
# 2  ['Areas of Interest Deep Learning, Control Sys...
# 3  ['Skills â\x80¢ R â\x80¢ Python â\x80¢ SAP HAN...
# 4                                                 []

# %%
if __name__ == "__main__":
    main()
# Out:
# 2025-05-09 09:16:40,363 - INFO - 데이터 크기: (962, 2)
# 2025-05-09 09:16:40,364 - INFO -
# 데이터 정보:
# 2025-05-09 09:16:40,374 - INFO - None
# 2025-05-09 09:16:40,375 - INFO -
# 카테고리 목록:
# 2025-05-09 09:16:40,375 - INFO - ['Data Science' 'HR' 'Advocate' 'Arts' 'Web Designing'
#  'Mechanical Engineer' 'Sales' 'Health and fitness' 'Civil Engineer'
#  'Java Developer' 'Business Analyst' 'SAP Developer' 'Automation Testing'
#  'Electrical Engineering' 'Operations Manager' 'Python Developer'
#  'DevOps Engineer' 'Network Security Engineer' 'PMO' 'Database' 'Hadoop'
#  'ETL Developer' 'DotNet Developer' 'Blockchain' 'Testing']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  962 non-null    object
#  1   Resume    962 non-null    object
# dtypes: object(2)
# memory usage: 15.2+ KB
# 2025-05-09 09:16:42,757 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'python', 'angular', 'javascript', 'sql', 'git', 'numpy', 'machine learning', 'mysql', 'docker', 'css', 'node.js', 'flask', 'html']
# 2025-05-09 09:16:42,759 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,760 - INFO - Extracted skills: ['matlab', 'java', 'deep learning', 'python', 'sql', 'machine learning', 'linux', 'mysql', 'flask']
# 2025-05-09 09:16:42,762 - INFO - Extracted skills: ['deep learning', 'c', 'python', 'sql', 'machine learning']
# 2025-05-09 09:16:42,763 - INFO - Extracted skills: ['java', 'c', 'python']
# 2025-05-09 09:16:42,764 - INFO - Extracted skills: ['matlab', 'c', 'python', 'machine learning', 'html']
# 2025-05-09 09:16:42,765 - INFO - Extracted skills: ['python', 'machine learning']
# 2025-05-09 09:16:42,768 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'c', 'python', 'sql', 'numpy', 'tensorflow', 'machine learning', 'linux', 'c++', 'mysql']
# 2025-05-09 09:16:42,769 - INFO - Extracted skills: ['deep learning', 'pandas', 'python', 'sql', 'numpy', 'machine learning', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,770 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,772 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'python', 'angular', 'javascript', 'sql', 'git', 'numpy', 'machine learning', 'mysql', 'docker', 'css', 'node.js', 'flask', 'html']
# 2025-05-09 09:16:42,774 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,777 - INFO - Extracted skills: ['matlab', 'java', 'deep learning', 'python', 'sql', 'machine learning', 'linux', 'mysql', 'flask']
# 2025-05-09 09:16:42,783 - INFO - Extracted skills: ['deep learning', 'c', 'python', 'sql', 'machine learning']
# 2025-05-09 09:16:42,786 - INFO - Extracted skills: ['java', 'c', 'python']
# 2025-05-09 09:16:42,788 - INFO - Extracted skills: ['matlab', 'c', 'python', 'machine learning', 'html']
# 2025-05-09 09:16:42,791 - INFO - Extracted skills: ['python', 'machine learning']
# 2025-05-09 09:16:42,796 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'c', 'python', 'sql', 'numpy', 'tensorflow', 'machine learning', 'linux', 'c++', 'mysql']
# 2025-05-09 09:16:42,799 - INFO - Extracted skills: ['deep learning', 'pandas', 'python', 'sql', 'numpy', 'machine learning', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,804 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,807 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'python', 'angular', 'javascript', 'sql', 'git', 'numpy', 'machine learning', 'mysql', 'docker', 'css', 'node.js', 'flask', 'html']
# 2025-05-09 09:16:42,809 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,811 - INFO - Extracted skills: ['matlab', 'java', 'deep learning', 'python', 'sql', 'machine learning', 'linux', 'mysql', 'flask']
# 2025-05-09 09:16:42,814 - INFO - Extracted skills: ['deep learning', 'c', 'python', 'sql', 'machine learning']
# 2025-05-09 09:16:42,816 - INFO - Extracted skills: ['java', 'c', 'python']
# 2025-05-09 09:16:42,818 - INFO - Extracted skills: ['matlab', 'c', 'python', 'machine learning', 'html']
# 2025-05-09 09:16:42,820 - INFO - Extracted skills: ['python', 'machine learning']
# 2025-05-09 09:16:42,823 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'c', 'python', 'sql', 'numpy', 'tensorflow', 'machine learning', 'linux', 'c++', 'mysql']
# 2025-05-09 09:16:42,826 - INFO - Extracted skills: ['deep learning', 'pandas', 'python', 'sql', 'numpy', 'machine learning', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,829 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,830 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'python', 'angular', 'javascript', 'sql', 'git', 'numpy', 'machine learning', 'mysql', 'docker', 'css', 'node.js', 'flask', 'html']
# 2025-05-09 09:16:42,831 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,832 - INFO - Extracted skills: ['matlab', 'java', 'deep learning', 'python', 'sql', 'machine learning', 'linux', 'mysql', 'flask']
# 2025-05-09 09:16:42,835 - INFO - Extracted skills: ['deep learning', 'c', 'python', 'sql', 'machine learning']
# 2025-05-09 09:16:42,836 - INFO - Extracted skills: ['java', 'c', 'python']
# 2025-05-09 09:16:42,837 - INFO - Extracted skills: ['matlab', 'c', 'python', 'machine learning', 'html']
# 2025-05-09 09:16:42,838 - INFO - Extracted skills: ['python', 'machine learning']
# 2025-05-09 09:16:42,840 - INFO - Extracted skills: ['java', 'deep learning', 'pandas', 'c', 'python', 'sql', 'numpy', 'tensorflow', 'machine learning', 'linux', 'c++', 'mysql']
# 2025-05-09 09:16:42,842 - INFO - Extracted skills: ['deep learning', 'pandas', 'python', 'sql', 'numpy', 'machine learning', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,844 - INFO - Extracted skills: ['python', 'machine learning', 'aws']
# 2025-05-09 09:16:42,845 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,846 - INFO - Extracted skills: ['interview', 'employee', 'training']
# 2025-05-09 09:16:42,846 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,847 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,847 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,848 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,849 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,850 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,851 - INFO - Extracted skills: ['training']
# 2025-05-09 09:16:42,852 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,853 - INFO - Extracted skills: ['java', 'c']
# 2025-05-09 09:16:42,854 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,856 - INFO - Extracted skills: ['interview', 'employee', 'training']
# 2025-05-09 09:16:42,856 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,857 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,857 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,858 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,858 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,859 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,860 - INFO - Extracted skills: ['training']
# 2025-05-09 09:16:42,860 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,861 - INFO - Extracted skills: ['java', 'c']
# 2025-05-09 09:16:42,862 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,863 - INFO - Extracted skills: ['interview', 'employee', 'training']
# 2025-05-09 09:16:42,864 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,864 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,865 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,866 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,866 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,869 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,869 - INFO - Extracted skills: ['training']
# 2025-05-09 09:16:42,870 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,871 - INFO - Extracted skills: ['java', 'c']
# 2025-05-09 09:16:42,872 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,873 - INFO - Extracted skills: ['interview', 'employee', 'training']
# 2025-05-09 09:16:42,874 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,875 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,875 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,876 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,876 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,877 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,878 - INFO - Extracted skills: ['training']
# 2025-05-09 09:16:42,878 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,879 - INFO - Extracted skills: ['java', 'c']
# 2025-05-09 09:16:42,880 - INFO - Extracted skills: ['criminal', 'civil', 'c', 'court', 'legal']
# 2025-05-09 09:16:42,881 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,881 - INFO - Extracted skills: ['legal']
# 2025-05-09 09:16:42,882 - INFO - Extracted skills: ['court', 'legal', 'litigation']
# 2025-05-09 09:16:42,884 - INFO - Extracted skills: ['criminal', 'civil', 'court', 'legal']
# 2025-05-09 09:16:42,885 - INFO - Extracted skills: ['civil', 'court', 'legal']
# 2025-05-09 09:16:42,886 - INFO - Extracted skills: ['criminal', 'c']
# 2025-05-09 09:16:42,887 - INFO - Extracted skills: ['criminal', 'court', 'legal', 'litigation']
# 2025-05-09 09:16:42,887 - INFO - Extracted skills: ['court', 'legal']
# 2025-05-09 09:16:42,889 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,890 - INFO - Extracted skills: ['criminal', 'civil', 'c', 'court', 'legal']
# 2025-05-09 09:16:42,891 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,891 - INFO - Extracted skills: ['legal']
# 2025-05-09 09:16:42,892 - INFO - Extracted skills: ['court', 'legal', 'litigation']
# 2025-05-09 09:16:42,894 - INFO - Extracted skills: ['criminal', 'civil', 'court', 'legal']
# 2025-05-09 09:16:42,894 - INFO - Extracted skills: ['civil', 'court', 'legal']
# 2025-05-09 09:16:42,895 - INFO - Extracted skills: ['criminal', 'c']
# 2025-05-09 09:16:42,896 - INFO - Extracted skills: ['criminal', 'court', 'legal', 'litigation']
# 2025-05-09 09:16:42,897 - INFO - Extracted skills: ['court', 'legal']
# 2025-05-09 09:16:42,898 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,899 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,900 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,903 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,904 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,905 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,905 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,907 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,908 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,910 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,911 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,912 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,913 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,914 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,915 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,918 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,919 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,920 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,923 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,926 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,927 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,933 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,935 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,936 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,938 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,940 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,942 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,944 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,945 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,946 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,947 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,950 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,952 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,956 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:42,956 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,957 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,958 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,959 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,961 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,963 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,964 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,966 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:42,968 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,969 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,971 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,972 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,974 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:42,975 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,977 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,978 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,979 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,980 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:42,982 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,985 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,986 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,987 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,988 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:42,990 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,991 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:42,993 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,994 - INFO - Extracted skills: []
# 2025-05-09 09:16:42,995 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:42,997 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:42,998 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:43,001 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,002 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,003 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:43,005 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,006 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:43,008 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,009 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,010 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:43,012 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,013 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:43,015 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,016 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,018 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:43,019 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,021 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:43,022 - INFO - Extracted skills: ['angular', 'javascript', 'photoshop', 'ui']
# 2025-05-09 09:16:43,023 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,024 - INFO - Extracted skills: ['java', 'c', 'javascript', 'photoshop', 'ui', 'c++', 'adobe']
# 2025-05-09 09:16:43,027 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,028 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,029 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,030 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,031 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,034 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,035 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,036 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,037 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,037 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,041 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,042 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,043 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,044 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,045 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,048 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,050 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,051 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,052 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,052 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,056 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,057 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,058 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,059 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,059 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,062 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,063 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,064 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,065 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,066 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,070 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,071 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,072 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,073 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,073 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,077 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,077 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,078 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,079 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,080 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,080 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,081 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,085 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,086 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,087 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,088 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,089 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,090 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,092 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,092 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,093 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,094 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,095 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,098 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,100 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,102 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,103 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,105 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,106 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,106 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,107 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,108 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,109 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,110 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,111 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,112 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,113 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,115 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,118 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,119 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,120 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,121 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,124 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,127 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,130 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,133 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,134 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,137 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,139 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,140 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,141 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,141 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,143 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,144 - INFO - Extracted skills: ['c', 'fitness']
# 2025-05-09 09:16:43,146 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,149 - INFO - Extracted skills: ['wellness', 'nutrition', 'fitness']
# 2025-05-09 09:16:43,152 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,154 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,156 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,158 - INFO - Extracted skills: ['c', 'fitness']
# 2025-05-09 09:16:43,159 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,162 - INFO - Extracted skills: ['wellness', 'nutrition', 'fitness']
# 2025-05-09 09:16:43,163 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,164 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,166 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,168 - INFO - Extracted skills: ['c', 'fitness']
# 2025-05-09 09:16:43,171 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,173 - INFO - Extracted skills: ['wellness', 'nutrition', 'fitness']
# 2025-05-09 09:16:43,174 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,176 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,178 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,179 - INFO - Extracted skills: ['c', 'fitness']
# 2025-05-09 09:16:43,181 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,182 - INFO - Extracted skills: ['wellness', 'nutrition', 'fitness']
# 2025-05-09 09:16:43,184 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,186 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,188 - INFO - Extracted skills: ['trainer', 'fitness']
# 2025-05-09 09:16:43,190 - INFO - Extracted skills: ['c', 'fitness']
# 2025-05-09 09:16:43,195 - INFO - Extracted skills: ['nutrition', 'fitness']
# 2025-05-09 09:16:43,199 - INFO - Extracted skills: ['wellness', 'nutrition', 'fitness']
# 2025-05-09 09:16:43,205 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,207 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,210 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,213 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,216 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,218 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,221 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,221 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,223 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,225 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,228 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,230 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,234 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,235 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,238 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,239 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,240 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,241 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,243 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,244 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,246 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,247 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,248 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,250 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,251 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,252 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,253 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,255 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,255 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,256 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,257 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,257 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,258 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,259 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,260 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,261 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,262 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,263 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,263 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,264 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,266 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,268 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,269 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,269 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,270 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,271 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,272 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,273 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,274 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,275 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,276 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,277 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,277 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,278 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,280 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,281 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,283 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,284 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,285 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,286 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,286 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,287 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,288 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,289 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,290 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,291 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,291 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,292 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,293 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,294 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,295 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,296 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,297 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,297 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,301 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,302 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,304 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,307 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,308 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,309 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,310 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,311 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,312 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,315 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,317 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,318 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,319 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,320 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,321 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,322 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,323 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,324 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,327 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,330 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,331 - INFO - Extracted skills: ['java', 'javascript']
# 2025-05-09 09:16:43,334 - INFO - Extracted skills: ['java', 'c', 'angular', 'sql', 'postgresql', 'spring', 'linux', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,338 - INFO - Extracted skills: ['java', 'c', 'sql', 'c++']
# 2025-05-09 09:16:43,341 - INFO - Extracted skills: ['java', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,343 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate']
# 2025-05-09 09:16:43,344 - INFO - Extracted skills: ['jdbc', 'java', 'c', 'javascript', 'c++', 'hibernate', 'j2ee']
# 2025-05-09 09:16:43,345 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,346 - INFO - Extracted skills: ['jdbc', 'java', 'angular', 'javascript', 'spring', 'linux', 'hibernate', 'mysql', 'j2ee', 'html']
# 2025-05-09 09:16:43,347 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'c++', 'hibernate', 'mysql']
# 2025-05-09 09:16:43,350 - INFO - Extracted skills: ['java', 'c', 'sql', 'spring', 'hibernate', 'css', 'html']
# 2025-05-09 09:16:43,352 - INFO - Extracted skills: ['jdbc', 'java', 'mongodb', 'javascript', 'spring', 'hibernate', 'mysql', 'j2ee', 'css', 'html']
# 2025-05-09 09:16:43,354 - INFO - Extracted skills: ['java', 'c', 'angular', 'javascript', 'spring', 'spring boot', 'hibernate', 'mysql', 'css']
# 2025-05-09 09:16:43,354 - INFO - Extracted skills: ['java', 'javascript', 'spring', 'hibernate']
# 2025-05-09 09:16:43,355 - INFO - Extracted skills: ['java', 'sql', 'linux']
# 2025-05-09 09:16:43,357 - INFO - Extracted skills: ['analysis', 'requirement']
# 2025-05-09 09:16:43,359 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,362 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,366 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,368 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,369 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,371 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,376 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,377 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,379 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,382 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,387 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,390 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,392 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,395 - INFO - Extracted skills: ['analysis', 'requirement']
# 2025-05-09 09:16:43,396 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,400 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,405 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,407 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,409 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,413 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,418 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,420 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,422 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,426 - INFO - Extracted skills: ['java', 'analysis', 'c', 'javascript', 'workflow', 'linux', 'c++', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,430 - INFO - Extracted skills: ['analysis', 'sql', 'report', 'requirement']
# 2025-05-09 09:16:43,431 - INFO - Extracted skills: ['java', 'report', 'requirement', 'html']
# 2025-05-09 09:16:43,434 - INFO - Extracted skills: ['report']
# 2025-05-09 09:16:43,436 - INFO - Extracted skills: ['java', 'python', 'sql']
# 2025-05-09 09:16:43,439 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,441 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,441 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,442 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,443 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,445 - INFO - Extracted skills: ['java', 'python', 'sql']
# 2025-05-09 09:16:43,448 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,450 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,451 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,452 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,453 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,455 - INFO - Extracted skills: ['java', 'python', 'sql']
# 2025-05-09 09:16:43,458 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,459 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,460 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,461 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,462 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,463 - INFO - Extracted skills: ['java', 'python', 'sql']
# 2025-05-09 09:16:43,466 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,469 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,471 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,473 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,476 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,477 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,479 - INFO - Extracted skills: ['java', 'c', 'c++']
# 2025-05-09 09:16:43,482 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'machine learning', 'c++', 'html']
# 2025-05-09 09:16:43,485 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,487 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,489 - INFO - Extracted skills: ['html']
# 2025-05-09 09:16:43,490 - INFO - Extracted skills: ['java', 'sql']
# 2025-05-09 09:16:43,492 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,493 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,495 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,496 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,498 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,500 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,502 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,504 - INFO - Extracted skills: ['java', 'c', 'c++']
# 2025-05-09 09:16:43,506 - INFO - Extracted skills: ['java', 'c', 'javascript', 'sql', 'machine learning', 'c++', 'html']
# 2025-05-09 09:16:43,508 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,509 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,511 - INFO - Extracted skills: ['html']
# 2025-05-09 09:16:43,511 - INFO - Extracted skills: ['java', 'sql']
# 2025-05-09 09:16:43,513 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,514 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,516 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,518 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,520 - INFO - Extracted skills: ['c', 'python', 'javascript', 'sql', 'linux', 'c++', 'mysql', 'html']
# 2025-05-09 09:16:43,521 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,523 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,524 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,526 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,527 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,528 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,530 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,530 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,532 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,536 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,537 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,539 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,540 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,541 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,542 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,543 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,545 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,546 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,548 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,550 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,551 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,553 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,554 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,556 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,556 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,558 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,560 - INFO - Extracted skills: ['voltage', 'control']
# 2025-05-09 09:16:43,561 - INFO - Extracted skills: ['control']
# 2025-05-09 09:16:43,563 - INFO - Extracted skills: ['switchgear', 'plc', 'control']
# 2025-05-09 09:16:43,563 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,565 - INFO - Extracted skills: ['switchgear', 'c', 'plc', 'control', 'circuit']
# 2025-05-09 09:16:43,569 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,571 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,575 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,580 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,584 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,588 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,593 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,598 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,602 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,604 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,609 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,614 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,619 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,622 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,626 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,630 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,635 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,637 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,642 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,646 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,650 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,653 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,657 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,662 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,666 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,668 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,672 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,677 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,681 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,684 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,688 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,694 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,701 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,705 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,712 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,719 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,724 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:43,729 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,734 - INFO - Extracted skills: []
# 2025-05-09 09:16:43,738 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:43,739 - INFO - Extracted skills: ['java', 'mongodb', 'c', 'python', 'angular', 'sql', 'postgresql', 'git', 'mysql', 'css', 'api', 'django', 'flask', 'html']
# 2025-05-09 09:16:43,740 - INFO - Extracted skills: ['python']
# 2025-05-09 09:16:43,740 - INFO - Extracted skills: ['c', 'python', 'tensorflow', 'c++', 'mysql']
# 2025-05-09 09:16:43,741 - INFO - Extracted skills: ['mongodb', 'python', 'git', 'mysql', 'css', 'api', 'django', 'html']
# 2025-05-09 09:16:43,743 - INFO - Extracted skills: ['python', 'git', 'mysql', 'api', 'django']
# 2025-05-09 09:16:43,744 - INFO - Extracted skills: ['java', 'pandas', 'c', 'python', 'mysql', 'django', 'html']
# 2025-05-09 09:16:43,745 - INFO - Extracted skills: ['java', 'mongodb', 'c', 'python', 'angular', 'sql', 'postgresql', 'git', 'mysql', 'css', 'api', 'django', 'flask', 'html']
# 2025-05-09 09:16:43,746 - INFO - Extracted skills: ['python']
# 2025-05-09 09:16:43,746 - INFO - Extracted skills: ['c', 'python', 'tensorflow', 'c++', 'mysql']
# 2025-05-09 09:16:43,748 - INFO - Extracted skills: ['mongodb', 'python', 'git', 'mysql', 'css', 'api', 'django', 'html']
# 2025-05-09 09:16:43,749 - INFO - Extracted skills: ['python', 'git', 'mysql', 'api', 'django']
# 2025-05-09 09:16:43,750 - INFO - Extracted skills: ['java', 'pandas', 'c', 'python', 'mysql', 'django', 'html']
# 2025-05-09 09:16:43,751 - INFO - Extracted skills: ['java', 'mongodb', 'c', 'python', 'angular', 'sql', 'postgresql', 'git', 'mysql', 'css', 'api', 'django', 'flask', 'html']
# 2025-05-09 09:16:43,752 - INFO - Extracted skills: ['python']
# 2025-05-09 09:16:43,752 - INFO - Extracted skills: ['c', 'python', 'tensorflow', 'c++', 'mysql']
# 2025-05-09 09:16:43,753 - INFO - Extracted skills: ['mongodb', 'python', 'git', 'mysql', 'css', 'api', 'django', 'html']
# 2025-05-09 09:16:43,755 - INFO - Extracted skills: ['python', 'git', 'mysql', 'api', 'django']
# 2025-05-09 09:16:43,755 - INFO - Extracted skills: ['java', 'pandas', 'c', 'python', 'mysql', 'django', 'html']
# 2025-05-09 09:16:43,757 - INFO - Extracted skills: ['java', 'mongodb', 'c', 'python', 'angular', 'sql', 'postgresql', 'git', 'mysql', 'css', 'api', 'django', 'flask', 'html']
# 2025-05-09 09:16:43,757 - INFO - Extracted skills: ['python']
# 2025-05-09 09:16:43,758 - INFO - Extracted skills: ['c', 'python', 'tensorflow', 'c++', 'mysql']
# 2025-05-09 09:16:43,759 - INFO - Extracted skills: ['mongodb', 'python', 'git', 'mysql', 'css', 'api', 'django', 'html']
# 2025-05-09 09:16:43,760 - INFO - Extracted skills: ['python', 'git', 'mysql', 'api', 'django']
# 2025-05-09 09:16:43,761 - INFO - Extracted skills: ['java', 'pandas', 'c', 'python', 'mysql', 'django', 'html']
# 2025-05-09 09:16:43,762 - INFO - Extracted skills: ['java', 'mongodb', 'c', 'python', 'angular', 'sql', 'postgresql', 'git', 'mysql', 'css', 'api', 'django', 'flask', 'html']
# 2025-05-09 09:16:43,762 - INFO - Extracted skills: ['python']
# 2025-05-09 09:16:43,763 - INFO - Extracted skills: ['c', 'python', 'tensorflow', 'c++', 'mysql']
# 2025-05-09 09:16:43,764 - INFO - Extracted skills: ['mongodb', 'python', 'git', 'mysql', 'css', 'api', 'django', 'html']
# 2025-05-09 09:16:43,765 - INFO - Extracted skills: ['python', 'git', 'mysql', 'api', 'django']
# 2025-05-09 09:16:43,766 - INFO - Extracted skills: ['java', 'pandas', 'c', 'python', 'mysql', 'django', 'html']
# ...
# 2025-05-09 09:16:44,211 - INFO - Extracted skills: ['sql', 'mysql', 'aws']
# 2025-05-09 09:16:44,212 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,213 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,215 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,217 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,219 - INFO - Extracted skills: ['sql', 'mysql', 'aws']
# 2025-05-09 09:16:44,219 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,221 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,222 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,224 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,225 - INFO - Extracted skills: ['sql', 'mysql', 'aws']
# 2025-05-09 09:16:44,226 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,227 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,229 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,230 - INFO - Extracted skills: ['sql']
# 2025-05-09 09:16:44,232 - INFO - Extracted skills: ['sql', 'mysql', 'aws']
# 2025-05-09 09:16:44,233 - INFO - Extracted skills: ['c', 'sql']
# 2025-05-09 09:16:44,234 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'c++', 'css', 'html']
# 2025-05-09 09:16:44,235 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,235 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,236 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,237 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'git', 'html']
# 2025-05-09 09:16:44,240 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,241 - INFO - Extracted skills: ['c', 'angular', 'sql']
# 2025-05-09 09:16:44,241 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'c++', 'css', 'html']
# 2025-05-09 09:16:44,242 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,243 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,244 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,245 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'git', 'html']
# 2025-05-09 09:16:44,247 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,249 - INFO - Extracted skills: ['c', 'angular', 'sql']
# 2025-05-09 09:16:44,250 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'c++', 'css', 'html']
# 2025-05-09 09:16:44,251 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,252 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,252 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,254 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'git', 'html']
# 2025-05-09 09:16:44,256 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,257 - INFO - Extracted skills: ['c', 'angular', 'sql']
# 2025-05-09 09:16:44,258 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'c++', 'css', 'html']
# 2025-05-09 09:16:44,258 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,259 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,260 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,261 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'git', 'html']
# 2025-05-09 09:16:44,264 - INFO - Extracted skills: ['c', 'javascript', 'sql', 'css', 'html']
# 2025-05-09 09:16:44,266 - INFO - Extracted skills: ['c', 'angular', 'sql']
# 2025-05-09 09:16:44,267 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,271 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,272 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,274 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,276 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,277 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,278 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,279 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,280 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,281 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,283 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,286 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,288 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,291 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,293 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,294 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,297 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,300 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,303 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,305 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,307 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,308 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,309 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,310 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,311 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,313 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,315 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,317 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,320 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,322 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,323 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,324 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,325 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,326 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,327 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,328 - INFO - Extracted skills: ['blockchain']
# 2025-05-09 09:16:44,329 - INFO - Extracted skills: ['mongodb', 'blockchain', 'angular', 'postgresql', 'react', 'mysql', 'docker', 'aws', 'ethereum', 'node.js']
# 2025-05-09 09:16:44,330 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'python', 'c++', 'mysql', 'ethereum']
# 2025-05-09 09:16:44,332 - INFO - Extracted skills: ['java', 'smart contract', 'blockchain', 'c', 'angular', 'javascript', 'sql', 'postgresql', 'c++', 'react', 'mysql', 'ethereum', 'css', 'html']
# 2025-05-09 09:16:44,334 - INFO - Extracted skills: ['java', 'blockchain', 'c', 'machine learning', 'ethereum']
# 2025-05-09 09:16:44,335 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,336 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,337 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,339 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,340 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,341 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,342 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,344 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,345 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,346 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,348 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,352 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,353 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,355 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,356 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,358 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,361 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,364 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,367 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,370 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,371 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,372 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,374 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,376 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,378 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,381 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,383 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,385 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,386 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,388 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,389 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,390 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,392 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,393 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,394 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,395 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,396 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,397 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,399 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,401 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,402 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,403 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,403 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,404 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,406 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,407 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,410 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,414 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,418 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,420 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,423 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,426 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,428 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,431 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,433 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,436 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,437 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,438 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,440 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,441 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,443 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,445 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,447 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:16:44,449 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,450 - INFO - Extracted skills: ['java', 'c', 'selenium', 'linux']
# 2025-05-09 09:16:44,452 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,453 - INFO - Extracted skills: ['c', 'c++']
# 2025-05-09 09:16:44,455 - INFO - Extracted skills: []
# 2025-05-09 09:16:44,456 - INFO - Extracted skills: ['c']
# 2025-05-09 09:16:44,457 - INFO - Extracted skills: ['java', 'bug tracking', 'sql', 'mysql', 'css', 'html']
# 2025-05-09 09:18:57,243 - INFO -
# 카테고리별 샘플 수:
# 2025-05-09 09:18:57,244 - INFO - Data Science: 40
# 2025-05-09 09:18:57,244 - INFO - HR: 44
# 2025-05-09 09:18:57,245 - INFO - Advocate: 20
# 2025-05-09 09:18:57,245 - INFO - Arts: 36
# 2025-05-09 09:18:57,246 - INFO - Web Designing: 45
# 2025-05-09 09:18:57,246 - INFO - Mechanical Engineer: 40
# 2025-05-09 09:18:57,246 - INFO - Sales: 40
# 2025-05-09 09:18:57,247 - INFO - Health and fitness: 30
# 2025-05-09 09:18:57,248 - INFO - Civil Engineer: 24
# 2025-05-09 09:18:57,248 - INFO - Java Developer: 84
# 2025-05-09 09:18:57,249 - INFO - Business Analyst: 28
# 2025-05-09 09:18:57,249 - INFO - SAP Developer: 24
# 2025-05-09 09:18:57,250 - INFO - Automation Testing: 26
# 2025-05-09 09:18:57,250 - INFO - Electrical Engineering: 30
# 2025-05-09 09:18:57,251 - INFO - Operations Manager: 40
# 2025-05-09 09:18:57,252 - INFO - Python Developer: 48
# 2025-05-09 09:18:57,252 - INFO - DevOps Engineer: 55
# 2025-05-09 09:18:57,252 - INFO - Network Security Engineer: 25
# 2025-05-09 09:18:57,254 - INFO - PMO: 30
# 2025-05-09 09:18:57,254 - INFO - Database: 33
# 2025-05-09 09:18:57,255 - INFO - Hadoop: 42
# 2025-05-09 09:18:57,255 - INFO - ETL Developer: 40
# 2025-05-09 09:18:57,256 - INFO - DotNet Developer: 28
# 2025-05-09 09:18:57,257 - INFO - Blockchain: 40
# 2025-05-09 09:18:57,257 - INFO - Testing: 70
# 2025-05-09 09:18:57,276 - INFO -
# 샘플 인덱스: 5
# 2025-05-09 09:18:57,277 - INFO - 원문 Resume 요약: SKILLS C Basics, IOT, Python, MATLAB, Data Science, Machine Learning, HTML, Microsoft Word, Microsoft Excel, Microsoft Powerpoint. RECOGNITION Academic Secured First place in B.Tech.Education Details
# August 2014 to May 2018 B.Tech.  Ghatkesar, Andhra Pradesh Aurora's Scientific and Technological I ...
# 2025-05-09 09:18:57,278 - INFO - 정제된 Resume: skill basic iot python matlab data science machine learning html microsoft word microsoft excel microsoft powerpoint recognition academic secured first place tech education detail 2014 2018 tech ghatkesar andhra pradesh aurora scientific technological institute 2012 2014 secondary education warangal ...
# 2025-05-09 09:18:57,279 - INFO - 기술 스택: ['python', 'matlab', 'machine learning', 'c', 'html']
# 2025-05-09 09:18:57,280 - INFO - 학력 정보: [{'degree': ['b.tech'], 'institution': None, 'year': 'august 2014 to may 2018'}]
# 2025-05-09 09:18:57,282 - INFO - 경력 정보: []
# 2025-05-09 09:18:57,341 - INFO - 전처리된 데이터 저장 완료: ./src/ProcessedResumeDataSet.json
